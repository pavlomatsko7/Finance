# %%
import quandl

# %%
mydata = quandl.get("FINRA/FNRA_SPY")

# %%
mydata
# Out:
#             ShortVolume  ShortExemptVolume  TotalVolume
# Date
# 2014-02-13     359615.0                0.0     430752.0
# 2014-02-14     461876.0                0.0     562968.0
# 2014-02-18     416787.0                0.0     578545.0
# 2014-02-19     593545.0                0.0     818643.0
# 2014-02-20     650276.0                0.0     974885.0
# 2014-02-21     331383.0                0.0     449594.0
# 2014-02-24     861467.0                0.0    1041127.0
# 2014-02-25     565308.0                0.0     712033.0
# 2014-02-26     563537.0                0.0     735650.0
# 2014-02-27     549503.0                0.0     911166.0
# 2014-02-28    1007079.0              200.0    1408867.0
# 2014-03-03    1111345.0                0.0    1559003.0
# 2014-03-04     868264.0                0.0    1029643.0
# 2014-03-05     567224.0                0.0     774201.0
# 2014-03-06     652419.0                0.0     954542.0
# 2014-03-07     711477.0                0.0    1001673.0
# ...

# %%
real_estate = quandl.get("ZILLOW/M362_IMP", authtoken="Gu7p_PV4mc5-LSG4Xdv4")

# %%
real_estate.plot()
